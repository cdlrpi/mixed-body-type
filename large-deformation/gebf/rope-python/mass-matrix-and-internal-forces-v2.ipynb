# %% [markdown]
# #Beam Element - This notebook computes the mass matrix and internal forces and outputs them for later use

# %%
import numpy as np
import scipy as sp
import sympy as sym
import pickle

from sympy import cos, sin

from IPython.display import display
from __future__ import division
from sympy.interactive import printing
printing.init_printing(use_latex='mathjax')

# %%
sym.mpmath.mp.pretty=True

# %%
def Skew_sym(v):
    """
    This function returns the skew symetric matrix 
    of the vector 'v' to affect the cross product of 'v'x'u'
    """
    v_skew = sym.Matrix([[  0 , -v[2],  v[1]],
                         [v[2],     0, -v[0]],
                         [-v[1],  v[0],    0]])
    return v_skew

# %%
def Rotate_sym(theta):
    """
    This function returns the symbolic rotation matrix 
    for the simple 2D-rotation about the third axis
    """
    R = sym.Matrix([[cos(theta), sin(theta), 0],
                   [-sin(theta), cos(theta), 0],[0,0,1]])
    return R

# %% [markdown]
# #### Define symbolic quantites

# %%
# nodal positons, velocities, and accelerations
"""
"""

# symbolic system parameters 
E, I, A, rho, x, l, tau_a = sym.symbols('E I A rho x l, tau_a')

# Beam coordinates at cross-section 1 and 2
r1 = sym.Matrix(['r_1x','r_1y'])
r2 = sym.Matrix(['r_2x','r_2y'])

# Deformation coordinates
u = sym.Matrix(['u_1x','u_1y','u_1z','u_2x','u_2y','u_2z'])
# u1 = sym.Matrix(['u_1x','u_1y','u_1z'])
# u2 = sym.Matrix(['u_2x','u_2y','u_2z'])
udot = sym.Matrix(['udot_1x','udot_1y','udot_1z','udot_2x','udot_2y','udot_2z'])
# u1dot = sym.Matrix(['udot_1x','udot_1y','udot_1z'])
# u2dot = sym.Matrix(['udot_2x','udot_2y','udot_2z'])
uddot = sym.Matrix(['uddot_1x','uddot_1y','uddot_1z','uddot_2x','uddot_2y','uddot_2z'])
# u1ddot = sym.Matrix(['uddot_1x','uddot_1y','uddot_1z'])
# u2ddot = sym.Matrix(['uddot_2x','uddot_2y','uddot_2z'])

theta1 = sym.Matrix(sym.symarray('theta',4))
theta2 = sym.Matrix(sym.symarray('phi',4))
theta1_dot = sym.Matrix(sym.symarray('thetadot',4))
theta2_dot = sym.Matrix(sym.symarray('phidot',4))
theta1_ddot = sym.Matrix(sym.symarray('thetaddot',4))
theta2_ddot = sym.Matrix(sym.symarray('phiddot',4))

# locating the point in the cross section
s1 = sym.Matrix([0, r1])
s2 = sym.Matrix([0, r2])
s = sym.Matrix.vstack(s1,s2)

# define state variables
# e = sym.Matrix([u1, [theta1[3]], u2, [theta2[3]]])
e = sym.Matrix([u[0:3,0], [theta1[3]], u[3:6,0], [theta2[3]]])
# define state variables
edot = sym.Matrix([udot[0:3,0], [theta1_dot[3]], udot[3:6,0], [theta2_dot[3]]])
# edot = sym.Matrix([u1dot, [theta1_dot[3]], u2dot, [theta2_dot[3]]])
eddot = sym.Matrix([uddot[0:3,0], [theta1_ddot[3]], uddot[3:6,0], [theta2_ddot[3]]])
# eddot = sym.Matrix([u1ddot, [theta1_ddot[3]], u2ddot, [theta2_ddot[3]]])
display(e)
# Out:
# ⎡u₁ₓ ⎤
# ⎢    ⎥
# ⎢u_1y⎥
# ⎢    ⎥
# ⎢u_1z⎥
# ⎢    ⎥
# ⎢ θ₃ ⎥
# ⎢    ⎥
# ⎢u₂ₓ ⎥
# ⎢    ⎥
# ⎢u_2y⎥
# ⎢    ⎥
# ⎢u_2z⎥
# ⎢    ⎥
# ⎣ φ₃ ⎦

# %% [markdown]
# ### Needed Matrix Quantities

# %%
# angular velocity for 2D case is trivial
omega1_skew = Skew_sym(theta1_dot[1:4])
omega2_skew = Skew_sym(theta2_dot[1:4])
alpha1_skew = Skew_sym(theta1_ddot[1:4])
alpha2_skew = Skew_sym(theta2_ddot[1:4])

R1 = Rotate_sym(theta1[3])
R2 = Rotate_sym(theta2[3])

R = sym.Matrix.vstack(sym.Matrix.hstack(R1,sym.zeros(3)), \
                      sym.Matrix.hstack(sym.zeros(3),R2))

Omega_skew = sym.Matrix.vstack(sym.Matrix.hstack(omega1_skew,sym.zeros(3)), \
                               sym.Matrix.hstack(sym.zeros(3),omega2_skew))

Alpha_skew = sym.Matrix.vstack(sym.Matrix.hstack(alpha1_skew,sym.zeros(3)), \
                               sym.Matrix.hstack(sym.zeros(3),alpha2_skew))
# display(Omega)

# %% [markdown]
# ### Define Kinematics

# %%
# Define velocity of element endpoints (nodes)
v = udot + R*Omega_skew*s
# v1 = u1dot + R1*omega1_skew*s1
# v2 = u2dot + R2*omega2_skew*s2
# v = sym.Matrix([v1,v2])
print('v = ')
display(v)

# Define acceleration of element endpoints (nodes)
a = uddot + R*Omega_skew*Omega_skew*s + R*Alpha_skew*s
# a1 = u1ddot + R1*omega1_skew*omega1_skew*s1 + R1*alpha1_skew*s1
# a2 = u2ddot + R2*omega2_skew*omega2_skew*s2 + R2*alpha2_skew*s2
# a = sym.Matrix([a1,a2])
print('\na = ')
display(a)
# Out:
# v =
# ⎡-r₁ₓ⋅θ̇₃⋅cos(θ₃) + r_1y⋅(-θ̇₁⋅sin(θ₃) + θ̇₂⋅cos(θ₃)) + u̇₁ₓ⎤
# ⎢                                                           ⎥
# ⎢r₁ₓ⋅θ̇₃⋅sin(θ₃) + r_1y⋅(-θ̇₁⋅cos(θ₃) - θ̇₂⋅sin(θ₃)) + u̇_1y⎥
# ⎢                                                           ⎥
# ⎢                      r₁ₓ⋅θ̇₁ + u̇_1z                      ⎥
# ⎢                                                           ⎥
# ⎢-φ̇₃⋅r₂ₓ⋅cos(φ₃) + r_2y⋅(-φ̇₁⋅sin(φ₃) + φ̇₂⋅cos(φ₃)) + u̇₂ₓ⎥
# ⎢                                                           ⎥
# ⎢φ̇₃⋅r₂ₓ⋅sin(φ₃) + r_2y⋅(-φ̇₁⋅cos(φ₃) - φ̇₂⋅sin(φ₃)) + u̇_2y⎥
# ⎢                                                           ⎥
# ⎣                      φ̇₁⋅r₂ₓ + u̇_2z                      ⎦
# a =
# ⎡                       ⎛                                      2        ⎞
# ⎢-r₁ₓ⋅θ̈₃⋅cos(θ₃) + r₁ₓ⋅⎝θ̇₁⋅(-θ̇₁⋅sin(θ₃) + θ̇₂⋅cos(θ₃)) - θ̇₃ ⋅sin(θ₃)⎠ + r_
# ⎢
# ⎢                      ⎛                                      2        ⎞
# ⎢r₁ₓ⋅θ̈₃⋅sin(θ₃) + r₁ₓ⋅⎝θ̇₁⋅(-θ̇₁⋅cos(θ₃) - θ̇₂⋅sin(θ₃)) - θ̇₃ ⋅cos(θ₃)⎠ + r_1
# ⎢
# ⎢
# ⎢                                                     r₁ₓ⋅θ̈₁ + r₁ₓ⋅θ̇₂⋅θ̇₃ +
# ⎢
# ⎢                       ⎛                                      2        ⎞
# ⎢-φ̈₃⋅r₂ₓ⋅cos(φ₃) + r₂ₓ⋅⎝φ̇₁⋅(-φ̇₁⋅sin(φ₃) + φ̇₂⋅cos(φ₃)) - φ̇₃ ⋅sin(φ₃)⎠ + r_
# ⎢
# ⎢                      ⎛                                      2        ⎞
# ⎢φ̈₃⋅r₂ₓ⋅sin(φ₃) + r₂ₓ⋅⎝φ̇₁⋅(-φ̇₁⋅cos(φ₃) - φ̇₂⋅sin(φ₃)) - φ̇₃ ⋅cos(φ₃)⎠ + r_2
# ⎢
# ⎢
# ⎣                                                     φ̈₁⋅r₂ₓ + φ̇₂⋅φ̇₃⋅r₂ₓ +
#
#
# 1y⋅(-θ̈₁⋅sin(θ₃) + θ̈₂⋅cos(θ₃)) + r_1y⋅(θ̇₁⋅θ̇₃⋅cos(θ₃) + θ̇₂⋅θ̇₃⋅sin(θ₃)) + u
#
#
# y⋅(-θ̈₁⋅cos(θ₃) - θ̈₂⋅sin(θ₃)) + r_1y⋅(-θ̇₁⋅θ̇₃⋅sin(θ₃) + θ̇₂⋅θ̇₃⋅cos(θ₃)) + u
#
#      ⎛     2      2⎞
# r_1y⋅⎝- θ̇₁  - θ̇₂ ⎠ + ü_1z
#
#
# 2y⋅(-φ̈₁⋅sin(φ₃) + φ̈₂⋅cos(φ₃)) + r_2y⋅(φ̇₁⋅φ̇₃⋅cos(φ₃) + φ̇₂⋅φ̇₃⋅sin(φ₃)) + u
#
#
# y⋅(-φ̈₁⋅cos(φ₃) - φ̈₂⋅sin(φ₃)) + r_2y⋅(-φ̇₁⋅φ̇₃⋅sin(φ₃) + φ̇₂⋅φ̇₃⋅cos(φ₃)) + u
#
#      ⎛     2      2⎞
# r_2y⋅⎝- φ̇₁  - φ̇₂ ⎠ + ü_2z
#
#     ⎤
# ̈₁ₓ ⎥
#     ⎥
#     ⎥
# ̈_1y⎥
#     ⎥
#     ⎥
#     ⎥
#     ⎥
#     ⎥
# ̈₂ₓ ⎥
#     ⎥
#     ⎥
# ̈_2y⎥
#     ⎥
#     ⎥
#     ⎦

# %% [markdown]
# ### Compute the Mass Matrix

# %%
# Define shape function for element with one node at each end
h = sym.symarray('h', 2)

h[0] = 1/2*(1 - x)
h[1] = 1/2*(1 + x)

# Compute shape function matrix
H = sym.expand(sym.Matrix([h[0]*sym.eye(3), h[1]*sym.eye(3)])).T
# print('\nH = ')
# display(H)

# Define velocity of any point 
Vp = H*v
# print('\nV = ')
# display(V)

# Define velocity of any point 
Ap = H*a
# print('\nA = ')
# display(Accel)

# Compute partial velocities of the nodes
Vr = sym.Matrix([[sym.diff(Vp[j],edot[i]) 
                         for j in range(len(V))] for i in range(len(edot))]).T

# v_r = H
print('\nVr = ')
display(Vr)

# Compute mass matrix
M = sym.Matrix([[sym.expand(sym.integrate(Vr[:,i].dot(Ap)*rho*A,(x,0,l))).coeff(eddot[j]) for i in range(len(eddot))]
                for j in range(len(eddot))])
print('\nM = \n')
display(M)
pickle.dump( M, open( "mass-matrix.dump", "wb" ) )
# Out:
# Vr =
# ⎡-0.5⋅x + 0.5       0             0        -r₁ₓ⋅(-0.5⋅x + 0.5)⋅cos(θ₃)  0.5⋅x
# ⎢
# ⎢     0        -0.5⋅x + 0.5       0        r₁ₓ⋅(-0.5⋅x + 0.5)⋅sin(θ₃)        0
# ⎢
# ⎣     0             0        -0.5⋅x + 0.5               0                    0
#
# + 0.5       0            0       -r₂ₓ⋅(0.5⋅x + 0.5)⋅cos(φ₃)⎤
#                                                            ⎥
#        0.5⋅x + 0.5       0       r₂ₓ⋅(0.5⋅x + 0.5)⋅sin(φ₃) ⎥
#                                                            ⎥
#             0       0.5⋅x + 0.5              0             ⎦
# M =
# ⎡                                         3             2
# ⎢                   0.0833333333333333⋅A⋅l ⋅ρ - 0.25⋅A⋅l ⋅ρ + 0.25⋅A⋅l⋅ρ
# ⎢
# ⎢
# ⎢                                            0
# ⎢
# ⎢
# ⎢                                            0
# ⎢
# ⎢                        3                         2
# ⎢- 0.0833333333333333⋅A⋅l ⋅r₁ₓ⋅ρ⋅cos(θ₃) + 0.25⋅A⋅l ⋅r₁ₓ⋅ρ⋅cos(θ₃) - 0.25⋅A⋅l⋅
# ⎢
# ⎢                                                 3
# ⎢                         - 0.0833333333333333⋅A⋅l ⋅ρ + 0.25⋅A⋅l⋅ρ
# ⎢
# ⎢
# ⎢                                            0
# ⎢
# ⎢
# ⎢                                            0
# ⎢
# ⎢                                    3
# ⎣              0.0833333333333333⋅A⋅l ⋅r₂ₓ⋅ρ⋅cos(φ₃) - 0.25⋅A⋅l⋅r₂ₓ⋅ρ⋅cos(φ₃)
#
#
#                                                           0
#
#                                                        3             2
#                                  0.0833333333333333⋅A⋅l ⋅ρ - 0.25⋅A⋅l ⋅ρ + 0.2
#
#
#                                                           0
#
#                                      3                         2
# r₁ₓ⋅ρ⋅cos(θ₃)  0.0833333333333333⋅A⋅l ⋅r₁ₓ⋅ρ⋅sin(θ₃) - 0.25⋅A⋅l ⋅r₁ₓ⋅ρ⋅sin(θ₃)
#
#
#                                                           0
#
#                                                                3
#                                        - 0.0833333333333333⋅A⋅l ⋅ρ + 0.25⋅A⋅l⋅
#
#
#                                                           0
#
#                                                    3
#                            - 0.0833333333333333⋅A⋅l ⋅r₂ₓ⋅ρ⋅sin(φ₃) + 0.25⋅A⋅l⋅
#
#
#                                                     0
#
#
# 5⋅A⋅l⋅ρ                                             0
#
#                                                  3             2
#                            0.0833333333333333⋅A⋅l ⋅ρ - 0.25⋅A⋅l ⋅ρ + 0.25⋅A⋅l⋅
#
#
#  + 0.25⋅A⋅l⋅r₁ₓ⋅ρ⋅sin(θ₃)                           0
#
#
#                                                     0
#
#
# ρ                                                   0
#
#                                                          3
#                                  - 0.0833333333333333⋅A⋅l ⋅ρ + 0.25⋅A⋅l⋅ρ
#
#
# r₂ₓ⋅ρ⋅sin(φ₃)                                       0
#
#                                                                              3
#                                                      - 0.0833333333333333⋅A⋅l
#
#                                                                             3
#                                                       0.0833333333333333⋅A⋅l ⋅
#
#
# ρ
#
#                          3    2      2                             3    2
#    0.0833333333333333⋅A⋅l ⋅r₁ₓ ⋅ρ⋅sin (θ₃) + 0.0833333333333333⋅A⋅l ⋅r₁ₓ ⋅ρ⋅co
#
#
#                                                                    0.083333333
#
#
#                                                                   - 0.08333333
#
#
#
#
#                                   3
#           - 0.0833333333333333⋅A⋅l ⋅r₁ₓ⋅r₂ₓ⋅ρ⋅sin(φ₃)⋅sin(θ₃) - 0.083333333333
#
#                          2
# ⋅r₁ₓ⋅ρ⋅cos(θ₃) + 0.25⋅A⋅l ⋅r₁ₓ⋅ρ⋅cos(θ₃) - 0.25⋅A⋅l⋅r₁ₓ⋅ρ⋅cos(θ₃)
#
#                         2
# r₁ₓ⋅ρ⋅sin(θ₃) - 0.25⋅A⋅l ⋅r₁ₓ⋅ρ⋅sin(θ₃) + 0.25⋅A⋅l⋅r₁ₓ⋅ρ⋅sin(θ₃)
#
#
#                     0
#
#  2               2    2      2               2    2      2                   2
# s (θ₃) - 0.25⋅A⋅l ⋅r₁ₓ ⋅ρ⋅sin (θ₃) - 0.25⋅A⋅l ⋅r₁ₓ ⋅ρ⋅cos (θ₃) + 0.25⋅A⋅l⋅r₁ₓ
#
#            3
# 3333333⋅A⋅l ⋅r₁ₓ⋅ρ⋅cos(θ₃) - 0.25⋅A⋅l⋅r₁ₓ⋅ρ⋅cos(θ₃)
#
#             3
# 33333333⋅A⋅l ⋅r₁ₓ⋅ρ⋅sin(θ₃) + 0.25⋅A⋅l⋅r₁ₓ⋅ρ⋅sin(θ₃)
#
#
#                     0
#
#         3
# 3333⋅A⋅l ⋅r₁ₓ⋅r₂ₓ⋅ρ⋅cos(φ₃)⋅cos(θ₃) + 0.25⋅A⋅l⋅r₁ₓ⋅r₂ₓ⋅ρ⋅sin(φ₃)⋅sin(θ₃) + 0.2
#
#
#                                                                  - 0.083333333
#
#
#
#
#
#
#
#       2                   2      2                                          3
# ⋅ρ⋅sin (θ₃) + 0.25⋅A⋅l⋅r₁ₓ ⋅ρ⋅cos (θ₃)                0.0833333333333333⋅A⋅l ⋅
#
#
#                                                            0.0833333333333333⋅
#
#
#
#
#
#
#
#                                                                 3
# 5⋅A⋅l⋅r₁ₓ⋅r₂ₓ⋅ρ⋅cos(φ₃)⋅cos(θ₃)         - 0.0833333333333333⋅A⋅l ⋅r₂ₓ⋅ρ⋅cos(φ₃
#
#            3
# 3333333⋅A⋅l ⋅ρ + 0.25⋅A⋅l⋅ρ
#
#
#       0
#
#
#       0
#
#
# r₁ₓ⋅ρ⋅cos(θ₃) - 0.25⋅A⋅l⋅r₁ₓ⋅ρ⋅cos(θ₃)                            - 0.08333333
#
#    3             2
# A⋅l ⋅ρ + 0.25⋅A⋅l ⋅ρ + 0.25⋅A⋅l⋅ρ
#
#
#       0                                                                 0.0833
#
#
#       0
#
#             2                                                               3
# ) - 0.25⋅A⋅l ⋅r₂ₓ⋅ρ⋅cos(φ₃) - 0.25⋅A⋅l⋅r₂ₓ⋅ρ⋅cos(φ₃)  0.0833333333333333⋅A⋅l ⋅
#
#
#                    0
#
#                         3
# - 0.0833333333333333⋅A⋅l ⋅ρ + 0.25⋅A⋅l⋅ρ
#
#
#                    0                                                    - 0.08
#
#             3
# 33333333⋅A⋅l ⋅r₁ₓ⋅ρ⋅sin(θ₃) + 0.25⋅A⋅l⋅r₁ₓ⋅ρ⋅sin(θ₃)
#
#
#                    0
#
#                 3             2
# 333333333333⋅A⋅l ⋅ρ + 0.25⋅A⋅l ⋅ρ + 0.25⋅A⋅l⋅ρ
#
#
#                    0                                              0.0833333333
#
#                         2
# r₂ₓ⋅ρ⋅sin(φ₃) + 0.25⋅A⋅l ⋅r₂ₓ⋅ρ⋅sin(φ₃) + 0.25⋅A⋅l⋅r₂ₓ⋅ρ⋅sin(φ₃)
#
#
#              0
#
#
#              0
#
#                   3
# 33333333333333⋅A⋅l ⋅ρ + 0.25⋅A⋅l⋅ρ
#
#                                                                          3
#              0                                   - 0.0833333333333333⋅A⋅l ⋅r₁ₓ
#
#
#              0
#
#
#              0
#
#           3             2
# 333333⋅A⋅l ⋅ρ + 0.25⋅A⋅l ⋅ρ + 0.25⋅A⋅l⋅ρ
#
#                                                                 3    2      2
#              0                            0.0833333333333333⋅A⋅l ⋅r₂ₓ ⋅ρ⋅sin (
#
#                                                   3
#                             0.0833333333333333⋅A⋅l ⋅r₂ₓ⋅ρ⋅cos(φ₃) - 0.25⋅A⋅l⋅r
#
#                                                    3
#                            - 0.0833333333333333⋅A⋅l ⋅r₂ₓ⋅ρ⋅sin(φ₃) + 0.25⋅A⋅l⋅
#
#
#                                                            0
#
#                                                3
# ⋅r₂ₓ⋅ρ⋅sin(φ₃)⋅sin(θ₃) - 0.0833333333333333⋅A⋅l ⋅r₁ₓ⋅r₂ₓ⋅ρ⋅cos(φ₃)⋅cos(θ₃) + 0
#
#                                       3                         2
#               - 0.0833333333333333⋅A⋅l ⋅r₂ₓ⋅ρ⋅cos(φ₃) - 0.25⋅A⋅l ⋅r₂ₓ⋅ρ⋅cos(φ₃
#
#                                      3                         2
#                0.0833333333333333⋅A⋅l ⋅r₂ₓ⋅ρ⋅sin(φ₃) + 0.25⋅A⋅l ⋅r₂ₓ⋅ρ⋅sin(φ₃)
#
#
#                                                            0
#
#                             3    2      2               2    2      2
# φ₃) + 0.0833333333333333⋅A⋅l ⋅r₂ₓ ⋅ρ⋅cos (φ₃) + 0.25⋅A⋅l ⋅r₂ₓ ⋅ρ⋅sin (φ₃) + 0.
#
#                                                                              ⎤
# ₂ₓ⋅ρ⋅cos(φ₃)                                                                 ⎥
#                                                                              ⎥
#                                                                              ⎥
# r₂ₓ⋅ρ⋅sin(φ₃)                                                                ⎥
#                                                                              ⎥
#                                                                              ⎥
#                                                                              ⎥
#                                                                              ⎥
#                                                                              ⎥
# .25⋅A⋅l⋅r₁ₓ⋅r₂ₓ⋅ρ⋅sin(φ₃)⋅sin(θ₃) + 0.25⋅A⋅l⋅r₁ₓ⋅r₂ₓ⋅ρ⋅cos(φ₃)⋅cos(θ₃)       ⎥
#                                                                              ⎥
#                                                                              ⎥
# ) - 0.25⋅A⋅l⋅r₂ₓ⋅ρ⋅cos(φ₃)                                                   ⎥
#                                                                              ⎥
#                                                                              ⎥
#  + 0.25⋅A⋅l⋅r₂ₓ⋅ρ⋅sin(φ₃)                                                    ⎥
#                                                                              ⎥
#                                                                              ⎥
#                                                                              ⎥
#                                                                              ⎥
#       2    2      2                   2      2                   2      2    ⎥
# 25⋅A⋅l ⋅r₂ₓ ⋅ρ⋅cos (φ₃) + 0.25⋅A⋅l⋅r₂ₓ ⋅ρ⋅sin (φ₃) + 0.25⋅A⋅l⋅r₂ₓ ⋅ρ⋅cos (φ₃)⎦

# %% [markdown]
# ### Compute Internal forces

# %% [markdown]
# #### Compute Longitudinal Strain Energy

# %% [markdown]
# #### Compute Transverse Strain Energy

# %% [markdown]
# #### Compute Internal Forces $Q_e = \frac{\partial U}{\partial e}$

# %% [markdown]
# ### Applied and body force vector
